# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Charts
#fill the missing values with numbers randomly drawn from distribution
#tree chart

# %%
#Import the Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Load the data sets- train and test 
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Look at top values of train data 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print the column names of train data
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data
df.shape
# Out:
# (891, 12)

# %%
#Print the number of missing values in each column of train and test data
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.countplot(x='Survived',data=df)
plt.subplot(2,2,2)
sns.countplot(x='Sex',data=df)
plt.subplot(2,2,3)
sns.countplot(data=df,x='Embarked')
plt.subplot(2,2,4)
sns.countplot(data=df,x='Pclass')
plt.show()

# %%
#Histogram of Age, Parch, Fare
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.histplot(data=df,x='Age',bins=20)
plt.subplot(2,2,2)
sns.histplot(data=df,x='Parch',bins=20)
plt.subplot(2,2,3)
sns.histplot(data=df,x='Fare',bins=20)
plt.show()

# %%
#Plot histogram of age for survived and did not survived class
sns.histplot(data=df,x='Survived')
plt.show()

# %%
#Count class and gender wise survival rate - plot with appropriate chart
#Age wise Distribution of Male and Female passengers
import seaborn as sns
import matplotlib.pyplot as plt

# Grouping by class and gender, and calculating survival rate
survival_rate = df.groupby(['Pclass', 'Sex'])['Survived'].mean().reset_index()

# Plotting
plt.figure(figsize=(8,6))
sns.barplot(data=survival_rate, x='Pclass', y='Survived', hue='Sex')
plt.title('Survival Rate by Class and Gender')
plt.ylabel('Survival Rate')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='Age', hue='Sex', bins=30, kde=True, element='step')
plt.title('Age-wise Distribution of Male and Female Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#Histogram of Age of the given data set(sample)
sns.histplot(data=df,x='Age')
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the missing values in Embarked column by 'S'
df['Embarked'].fillna('S',inplace=True)
df.isnull().sum()
# Out:
# C:\Users\Naresh Damera\AppData\Local\Temp\ipykernel_15260\2000005856.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S',inplace=True)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Impute the missing values in Fare column with median value
df['Fare'].fillna(df['Fare'].median(),inplace=True)
# Out:
# C:\Users\Naresh Damera\AppData\Local\Temp\ipykernel_15260\363213623.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(df['Fare'].median(),inplace=True)

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data

df['Age'] = df['Age'].apply(
    lambda x: np.random.normal(df['Age'].mean(), df['Age'].std()) if pd.isnull(x) else x
)

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1
df['FamilySize']=df['Parch']+df['SibSp']+1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  31.726628
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0        1      0         A/5 21171   7.2500   NaN        S           2
# 1        1      0          PC 17599  71.2833   C85        C           2
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S           1
# 3        1      0            113803  53.1000  C123        S           2
# 4        0      0            373450   8.0500   NaN        S           1
# ..     ...    ...               ...      ...   ...      ...         ...
# 886      0      0            211536  13.0000   NaN        S           1
# 887      0      0            112053  30.0000   B42        S           1
# 888      1      2        W./C. 6607  23.4500   NaN        S           4
# 889      0      0            111369  30.0000  C148        C           1
# 890      0      0            370376   7.7500   NaN        Q           1
#
# [891 rows x 13 columns]

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False

df['IsAlone']=df['FamilySize']==1

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin

df.drop(columns=['PassengerId','Name','Ticket','Cabin'], inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  31.726628      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#      FamilySize  IsAlone
# 0             2    False
# 1             2    False
# 2             1     True
# 3             2    False
# 4             1     True
# ..          ...      ...
# 886           1     True
# 887           1     True
# 888           4    False
# 889           1     True
# 890           1     True
#
# [891 rows x 10 columns]

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y
y=df['Survived']
X=df.drop(columns=['Survived'],axis=1)
print(y.shape)
print(X.shape)
# Out:
# (891,)
# (891, 9)

# %%
X
# Out:
#      Pclass     Sex        Age  SibSp  Parch     Fare Embarked  FamilySize  \
# 0         3    male  22.000000      1      0   7.2500        S           2
# 1         1  female  38.000000      1      0  71.2833        C           2
# 2         3  female  26.000000      0      0   7.9250        S           1
# 3         1  female  35.000000      1      0  53.1000        S           2
# 4         3    male  35.000000      0      0   8.0500        S           1
# ..      ...     ...        ...    ...    ...      ...      ...         ...
# 886       2    male  27.000000      0      0  13.0000        S           1
# 887       1  female  19.000000      0      0  30.0000        S           1
# 888       3  female  31.726628      1      2  23.4500        S           4
# 889       1    male  26.000000      0      0  30.0000        C           1
# 890       3    male  32.000000      0      0   7.7500        Q           1
#
#      IsAlone
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
# ..       ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
#
# [891 rows x 9 columns]

# %%
# Label encoding of categorical features

import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Label encode binary feature: 'Sex'
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    1  22.000000      1      0   7.2500        S
# 1           1       1    0  38.000000      1      0  71.2833        C
# 2           1       3    0  26.000000      0      0   7.9250        S
# 3           1       1    0  35.000000      1      0  53.1000        S
# 4           0       3    1  35.000000      0      0   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    1  27.000000      0      0  13.0000        S
# 887         1       1    0  19.000000      0      0  30.0000        S
# 888         0       3    0  31.726628      1      2  23.4500        S
# 889         1       1    1  26.000000      0      0  30.0000        C
# 890         0       3    1  32.000000      0      0   7.7500        Q
#
#      FamilySize  IsAlone
# 0             2    False
# 1             2    False
# 2             1     True
# 3             2    False
# 4             1     True
# ..          ...      ...
# 886           1     True
# 887           1     True
# 888           4    False
# 889           1     True
# 890           1     True
#
# [891 rows x 10 columns]

# %%
# concat df_categorical with original df
df = pd.get_dummies(df, columns=['Embarked'], prefix=['Embarked'], drop_first=True)
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  FamilySize  \
# 0           0       3    1  22.000000      1      0   7.2500           2
# 1           1       1    0  38.000000      1      0  71.2833           2
# 2           1       3    0  26.000000      0      0   7.9250           1
# 3           1       1    0  35.000000      1      0  53.1000           2
# 4           0       3    1  35.000000      0      0   8.0500           1
# ..        ...     ...  ...        ...    ...    ...      ...         ...
# 886         0       2    1  27.000000      0      0  13.0000           1
# 887         1       1    0  19.000000      0      0  30.0000           1
# 888         0       3    0  31.726628      1      2  23.4500           4
# 889         1       1    1  26.000000      0      0  30.0000           1
# 890         0       3    1  32.000000      0      0   7.7500           1
#
#      IsAlone  Embarked_Q  Embarked_S
# 0      False       False        True
# 1      False       False       False
# 2       True       False        True
# 3      False       False        True
# 4       True       False        True
# ..       ...         ...         ...
# 886     True       False        True
# 887     True       False        True
# 888    False       False        True
# 889     True       False       False
# 890     True        True       False
#
# [891 rows x 11 columns]

# %%
#Do a pairplot of all features
sns.pairplot(df)

# %%
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  FamilySize  \
# 0           0       3    1  22.000000      1      0   7.2500           2
# 1           1       1    0  38.000000      1      0  71.2833           2
# 2           1       3    0  26.000000      0      0   7.9250           1
# 3           1       1    0  35.000000      1      0  53.1000           2
# 4           0       3    1  35.000000      0      0   8.0500           1
# ..        ...     ...  ...        ...    ...    ...      ...         ...
# 886         0       2    1  27.000000      0      0  13.0000           1
# 887         1       1    0  19.000000      0      0  30.0000           1
# 888         0       3    0  31.726628      1      2  23.4500           4
# 889         1       1    1  26.000000      0      0  30.0000           1
# 890         0       3    1  32.000000      0      0   7.7500           1
#
#      IsAlone  Embarked_Q  Embarked_S
# 0      False       False        True
# 1      False       False       False
# 2       True       False        True
# 3      False       False        True
# 4       True       False        True
# ..       ...         ...         ...
# 886     True       False        True
# 887     True       False        True
# 888    False       False        True
# 889     True       False       False
# 890     True        True       False
#
# [891 rows x 11 columns]

# %%
y=df['Survived']
X=df.drop(columns=['Survived'],axis=1)

# %%
print(X.shape)
print(y.shape)
# Out:
# (891, 10)
# (891,)

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  FamilySize  IsAlone  \
# 205       3    0   2.000000      0      1  10.4625           2    False
# 548       3    1  33.000000      1      1  20.5250           3    False
# 346       2    0  40.000000      0      0  13.0000           1     True
# 471       3    1  38.000000      0      0   8.6625           1     True
# 9         2    0  14.000000      1      0  30.0708           2    False
# ..      ...  ...        ...    ...    ...      ...         ...      ...
# 95        3    1  36.787758      0      0   8.0500           1     True
# 292       2    1  36.000000      0      0  12.8750           1     True
# 28        3    0  33.161695      0      0   7.8792           1     True
# 210       3    1  24.000000      0      0   7.0500           1     True
# 590       3    1  35.000000      0      0   7.1250           1     True
#
#      Embarked_Q  Embarked_S
# 205       False        True
# 548       False        True
# 346       False        True
# 471       False        True
# 9         False       False
# ..          ...         ...
# 95        False        True
# 292       False       False
# 28         True       False
# 210       False        True
# 590       False        True
#
# [712 rows x 10 columns]

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library

# plotting tree with max_depth=3

from sklearn.tree import DecisionTreeClassifier,plot_tree

model = DecisionTreeClassifier(max_depth=3, random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
#Print the tree

# Importing required packages for visualization

plt.figure(figsize=(20,10))  # Set the figure size
plot_tree(model, 
          feature_names=X_train.columns, 
          class_names=[str(cls) for cls in model.classes_], 
          filled=True, 
          rounded=True)
plt.title("Decision Tree (max_depth=3)")
plt.show()

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score,confusion_matrix,classification_report
y_test_pred=model.predict(X_test)
p_score=precision_score(y_test,y_test_pred)
r_score=recall_score(y_test,y_test_pred)
f_score=f1_score(y_test,y_test_pred)

print("Precision=",p_score)
print("recall=",r_score)
print("f1 score=",f_score)




# Printing classification report
print(classification_report(y_test,y_test_pred))
# Out:
# Precision= 0.7272727272727273
# recall= 0.6486486486486487
# f1 score= 0.6857142857142857
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       105
#            1       0.73      0.65      0.69        74
#
#     accuracy                           0.75       179
#    macro avg       0.75      0.74      0.74       179
# weighted avg       0.75      0.75      0.75       179

# %%
# Printing confusion matrix and accuracy
a_score=accuracy_score(y_test,y_test_pred)
c_matrix=confusion_matrix(y_test,y_test_pred)

print("Accuracy=",a_score)
print("confusion matrix=",c_matrix)
# Out:
# Accuracy= 0.7541899441340782
# confusion matrix= [[87 18]
#  [26 48]]
